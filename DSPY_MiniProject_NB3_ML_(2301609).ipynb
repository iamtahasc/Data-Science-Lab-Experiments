# %% [markdown]
# <a href="https://colab.research.google.com/github/iamtahasc/Data-Science-Lab-Experiments/blob/main/DSPY_MiniProject_NB3_ML_(2301609).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Netflix Data Analysis - Machine Learning
#
# ## Objective
# The objective of this notebook is to build a machine learning model to classify whether a Netflix content is a Movie or a TV Show.
#
# ## Problem Type
# This is a Classification Problem.

# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_netflix.csv")
df.head()
# Out:
#    type         director                                               cast  \
# 0     0  Kirsten Johnson                                            Unknown
# 1     1          Unknown  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     1  Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3     1          Unknown                                            Unknown
# 4     1          Unknown  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#
#          country  date_added  release_year rating   duration  \
# 0  United States  2021-09-25          2020  PG-13     90 min
# 1   South Africa  2021-09-24          2021  TV-MA  2 Seasons
# 2        Unknown  2021-09-24          2021  TV-MA   1 Season
# 3        Unknown  2021-09-24          2021  TV-MA   1 Season
# 4          India  2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  year_added  duration_num
# ...

# %% [markdown]
# ## Dataset Loaded
#
# The cleaned dataset is loaded successfully and ready for machine learning.

# %% [markdown]
# ## Feature Selection
#
# We select important features for prediction:
# - release_year
# - duration_num
# - year_added

# %%
X = df[['release_year','duration_num','year_added']]
y = df['type']

# %% [markdown]
# ## Splitting Data
#
# We split the dataset into training and testing data.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Model Training
#
# We use Logistic Regression model for classification.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6897/1422245482.py in <cell line: 0>()
#       6 y_pred_dt = dt.predict(X_test)
#       7
# ----> 8 print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
#
# NameError: name 'accuracy_score' is not defined

# %% [markdown]
# ## Prediction
#
# We predict the output using the trained model.

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Model Evaluation
#
# We evaluate the model using accuracy score.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %% [markdown]
# ## Machine Learning Life Cycle
#
# 1. Data Collection
# 2. Data Cleaning
# 3. Feature Selection
# 4. Model Selection
# 5. Training
# 6. Testing
# 7. Evaluation

# %% [markdown]
# ## Conclusion
#
# We successfully built a machine learning model using Logistic Regression to classify Netflix content. The model was trained and evaluated using accuracy and confusion matrix.
